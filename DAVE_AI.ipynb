# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivisteria11/AI-chat-bot/blob/main/DAVE_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers requests pandas torch huggingface_hub

import requests
import pandas as pd
import json
from typing import List, Dict
import time
from datetime import datetime
from huggingface_hub import HfApi, InferenceApi
from transformers import pipeline

class MovieAnalyzer:
    def __init__(self):
        # Sign up at HuggingFace and get your token from: https://huggingface.co/settings/tokens
        self.HF_TOKEN = "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"  # Replace with your token

        # Initialize the generator using FLAN-T5-XL (free to use)
        self.generator = pipeline(
            "text2text-generation",
            model="google/flan-t5-large",
            max_length=200,
            device="cpu"  # Use "cuda" if you have GPU
        )

        # Sample movie dataset
        self.data = {
            'movie_title': [
                'Inception',
                'The Shawshank Redemption',
                'The Dark Knight'
            ],
            'genres': [
                'Action, Sci-Fi',
                'Drama',
                'Action, Crime'
            ],
            'description': [
                'Cobb and his team share the skill of entering one\'s dreams.',
                'Two imprisoned men bond over a number of years.',
                'Batman, Gordon, and Harvey Dent are forced to deal with the chaos unleashed by an anarchist mastermind.'
            ],
            'cast': [
                'Leonardo DiCaprio, Ellen Page',
                'Tim Robbins, Morgan Freeman',
                'Christian Bale, Heath Ledger'
            ]
        }
        self.df = pd.DataFrame(self.data)

    def generate_text(self, prompt: str, max_retries: int = 3) -> str:
        """Generate text using FLAN-T5"""
        for attempt in range(max_retries):
            try:
                # Generate text
                result = self.generator(
                    prompt,
                    max_length=200,
                    num_return_sequences=1,
                    do_sample=True,
                    temperature=0.9
                )
                return result[0]['generated_text']
            except Exception as e:
                if attempt == max_retries - 1:
                    return f"Error generating response: {str(e)}"
                time.sleep(2)

    def generate_creative_description(self, title: str, description: str) -> str:
        prompt = f"""Task: Create an engaging movie description
        Movie: {title}
        Original: {description}
        Write a compelling and detailed description that captures the essence of the movie.
        """
        return self.generate_text(prompt)

    def predict_genres(self, description: str) -> List[str]:
        prompt = f"""Task: Predict movie genres
        Description: {description}
        List the most appropriate genres for this movie (maximum 3 genres).
        """
        response = self.generate_text(prompt)
        # Clean up the response and split into genres
        genres = [g.strip() for g in response.split(',')]
        return genres[:3]  # Ensure maximum 3 genres

    def generate_plot_twist(self, title: str, description: str) -> str:
        prompt = f"""Task: Create a movie plot twist
        Movie: {title}
        Original plot: {description}
        Create a surprising but logical alternative ending or plot twist.
        """
        return self.generate_text(prompt)

    def analyze_movies(self) -> List[Dict]:
        """Process all movies and generate analysis"""
        outputs = []

        for _, row in self.df.iterrows():
            print(f"Processing: {row['movie_title']}")

            analysis = {
                'movie_title': row['movie_title'],
                'original_description': row['description'],
                'generated_description': self.generate_creative_description(
                    row['movie_title'], row['description']
                ),
                'original_genres': row['genres'],
                'predicted_genres': self.predict_genres(row['description']),
                'plot_twist': self.generate_plot_twist(
                    row['movie_title'], row['description']
                ),
                'cast': row['cast'],
                'analysis_timestamp': datetime.now().isoformat()
            }
            outputs.append(analysis)

            # Save progress
            self.save_outputs(outputs)

            # Add delay to prevent overloading
            time.sleep(2)

        return outputs

    def save_outputs(self, outputs: List[Dict], filename: str = 'movie_analysis_outputs.json'):
        """Save outputs to JSON file"""
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(outputs, f, indent=4, ensure_ascii=False)

    def display_outputs(self, outputs: List[Dict]):
        """Display formatted outputs"""
        for output in outputs:
            print("\n" + "="*50)
            print(f"Movie: {output['movie_title']}")
            print("-"*50)
            print(f"Generated Description:\n{output['generated_description']}\n")
            print(f"Original Genres: {output['original_genres']}")
            print(f"Predicted Genres: {', '.join(output['predicted_genres'])}\n")
            print(f"Plot Twist:\n{output['plot_twist']}\n")

# Alternative method using Hugging Face's inference API
class MovieAnalyzerInferenceAPI:
    def __init__(self, hf_token):
        self.api = HfApi()
        self.token = hf_token

    def generate_text(self, prompt: str) -> str:
        try:
            # Using FLAN-T5 through the Inference API
            api_url = "https://api-inference.huggingface.co/models/google/flan-t5-large"
            headers = {"Authorization": f"Bearer {self.token}"}

            response = requests.post(
                api_url,
                headers=headers,
                json={"inputs": prompt}
            )

            if response.status_code == 200:
                return response.json()[0]['generated_text']
            else:
                return f"Error: {response.status_code}"

        except Exception as e:
            return f"Error: {str(e)}"

# Example usage
def main():
    # Choose which version to use
    use_inference_api = False  # Set to True to use the Inference API instead

    if use_inference_api:
        # Replace with your HuggingFace token
        analyzer = MovieAnalyzerInferenceAPI("your-huggingface-token")
    else:
        analyzer = MovieAnalyzer()

    outputs = analyzer.analyze_movies()
    analyzer.display_outputs(outputs)
    print("\nAnalysis complete! Results saved to 'movie_analysis_outputs.json'")

if __name__ == "__main__":
    main()
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.24.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Processing: Inception
# Processing: The Shawshank Redemption
# Processing: The Dark Knight
#
# ==================================================
# Movie: Inception
# --------------------------------------------------
# Generated Description:
# This American remake of the 1970 classic story introduces the world to a new cast of characters including actors and directors that have a long history as a group. The cast features Kenneth Branagh, Robert De Niro, John Cusack, Tom Wilkinson, Adrien Brody, and Chris Cooper as main characters and features a stellar cast of supporting characters including Christopher Ryan and Ellen Barkin, David Strathairn. The film uses the same music and the same actors as the original, and with the addition of new characters. The opening credits re-tell the story of the American civil rights movement. The opening sequence is a montage of images of a woman being harassed by police. The first scene in the film shows a policeman chase a man through a wooded area. In this scene officers believe the man is a gang member and are called to the scene. They join an escape attempt
#
# Original Genres: Action, Sci-Fi
# Predicted Genres: SciFi/fantasy
#
# Plot Twist:
# From a remote cabin in the woods, Cobb spends his last night exploring the beautiful night sky, which he then witnesses from afar.
#
#
# ==================================================
# Movie: The Shawshank Redemption
# --------------------------------------------------
# Generated Description:
# The Shawshank Redemption is a story in which two prisoners of war, Henry Shawshank and William McKittrick, come together to learn of a conspiracy by the British Empire in the American South and form an alliance to oust their enemy.
#
# Original Genres: Drama
# Predicted Genres: Drama
#
# Plot Twist:
# The story also reveals the many differences between those two men.
#
#
# ==================================================
# Movie: The Dark Knight
# --------------------------------------------------
# Generated Description:
# A group of Batman's closest friends have a big surprise for a change as one of them, Gordon Gordon (Oliver Platt), discovers a large, atomic explosion at the location of his company, Dharma's Reactor (Luther Kwouk), causing huge chaos which changes the way Batman operates. While Batman, Gordon, and Harvey Dent are forced to deal with the chaos unleashed by an anarchist mastermind, the film never feels pretention.
#
# Original Genres: Action, Crime
# Predicted Genres: Action
#
# Plot Twist:
# The Batman and Harvey Dent families are forced to deal with the chaos unleashed by the first Batman, Gary Oldman's father. The family's new home is broken into by a mysterious and arrogant stranger named George Miller (John Sutherland), who is forced to move to a small house when his business suffers a financial loss.
#
#
# Analysis complete! Results saved to 'movie_analysis_outputs.json'

# %%
# Install required libraries
# !pip install transformers requests pandas torch huggingface_hub

import requests
import pandas as pd
import json
from typing import List, Dict
import time
from datetime import datetime
from huggingface_hub import HfApi, InferenceApi
from transformers import pipeline
import torch

# Check GPU availability
print("GPU is available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU being used:", torch.cuda.get_device_name(0))
    device = 0  # Use GPU
else:
    print("No GPU available, using CPU")
    device = "cpu"

class MovieAnalyzer:
    def __init__(self):
        self.HF_TOKEN = "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"  # Replace with your token

        # Initialize with GPU support
        self.generator = pipeline(
            "text2text-generation",
            model="google/flan-t5-large",
            max_length=200,
            device=device  # This will use GPU if available
        )

        # 20 movies dataset
        self.data = {
            'movie_title': [
                'Inception',
                'The Shawshank Redemption',
                'The Dark Knight',
                'Pulp Fiction',
                'The Matrix',
                'Forrest Gump',
                'The Godfather',
                'Jurassic Park',
                'Titanic',
                'The Silence of the Lambs',
                'Avatar',
                'The Lord of the Rings: The Fellowship of the Ring',
                'Goodfellas',
                'Fight Club',
                'The Green Mile',
                'Interstellar',
                'The Avengers',
                'Schindler\'s List',
                'The Lion King',
                'Star Wars: Episode IV - A New Hope'
            ],
            'genres': [
                'Action, Sci-Fi',
                'Drama',
                'Action, Crime',
                'Crime, Drama',
                'Sci-Fi, Action',
                'Drama, Romance',
                'Crime, Drama',
                'Adventure, Sci-Fi',
                'Drama, Romance',
                'Crime, Thriller',
                'Sci-Fi, Adventure',
                'Fantasy, Adventure',
                'Crime, Biography',
                'Drama, Thriller',
                'Crime, Drama, Fantasy',
                'Sci-Fi, Adventure',
                'Action, Sci-Fi',
                'Biography, Drama',
                'Animation, Adventure',
                'Sci-Fi, Adventure'
            ],
            'description': [
                'A skilled thief who enters dreams to steal secrets takes on an impossible task: planting an idea in someone\'s mind.',
                'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
                'When the Joker wreaks havoc on Gotham City, Batman must confront one of his most notorious enemies.',
                'Various interconnected stories of Los Angeles criminals, small-time mobsters, and other colorful characters.',
                'A computer programmer discovers humanity is trapped inside a simulated reality and joins a rebellion to break free.',
                'The life journey of a slow-witted but kind-hearted man as he witnesses and influences several historical events.',
                'The aging patriarch of an organized crime dynasty transfers control to his reluctant son.',
                'A theme park showcasing genetically recreated dinosaurs turns into a nightmare when the creatures escape.',
                'A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.',
                'A young FBI cadet must receive the help of an incarcerated and manipulative cannibal killer.',
                'A paraplegic marine dispatched to the moon Pandora becomes torn between following orders and protecting the world he feels is his home.',
                'A young hobbit and his friends embark on a quest to destroy a powerful ring and defeat the dark lord who created it.',
                'The story of Henry Hill and his life in the mob, covering his relationship with his wife Karen and his mob partners.',
                'An insomniac office worker and a devil-may-care soapmaker form an underground fight club.',
                'A tale of a gentle prison guard who discovers that a death row inmate possesses mysterious healing powers.',
                'A team of explorers travel through a wormhole in space in an attempt to ensure humanity\'s survival.',
                'Earth\'s mightiest heroes must come together and learn to fight as a team to stop an alien invasion.',
                'In German-occupied Poland during World War II, businessman Oskar Schindler gradually becomes concerned for his Jewish workforce.',
                'A young lion prince must overcome tragedy and take his rightful place as king of the Pride Lands.',
                'Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, and others to save Princess Leia and battle the Empire\'s world-destroying battle station.'
            ],
            'cast': [
                'Leonardo DiCaprio, Ellen Page',
                'Tim Robbins, Morgan Freeman',
                'Christian Bale, Heath Ledger',
                'John Travolta, Samuel L. Jackson',
                'Keanu Reeves, Laurence Fishburne',
                'Tom Hanks, Robin Wright',
                'Marlon Brando, Al Pacino',
                'Sam Neill, Laura Dern',
                'Leonardo DiCaprio, Kate Winslet',
                'Jodie Foster, Anthony Hopkins',
                'Sam Worthington, Zoe Saldana',
                'Elijah Wood, Ian McKellen',
                'Robert De Niro, Ray Liotta',
                'Brad Pitt, Edward Norton',
                'Tom Hanks, Michael Clarke Duncan',
                'Matthew McConaughey, Anne Hathaway',
                'Robert Downey Jr., Chris Evans',
                'Liam Neeson, Ben Kingsley',
                'Matthew Broderick, James Earl Jones',
                'Mark Hamill, Harrison Ford'
            ]
        }
        self.df = pd.DataFrame(self.data)

    def generate_text(self, prompt: str, max_retries: int = 3) -> str:
        """Generate text using FLAN-T5"""
        for attempt in range(max_retries):
            try:
                result = self.generator(
                    prompt,
                    max_length=250,
                    num_return_sequences=1,
                    do_sample=True,
                    temperature=0.9
                )
                return result[0]['generated_text']
            except Exception as e:
                if attempt == max_retries - 1:
                    return f"Error generating response: {str(e)}"
                time.sleep(2)

    def generate_creative_description(self, title: str, description: str) -> str:
        prompt = f"""Task: Create an engaging movie description
        Movie: {title}
        Original: {description}
        Write a compelling and detailed description that captures the essence of the movie."""
        return self.generate_text(prompt)

    def predict_genres(self, description: str) -> List[str]:
        prompt = f"""Task: Predict movie genres
        Description: {description}
        List the most appropriate genres for this movie (maximum 3 genres)."""
        response = self.generate_text(prompt)
        return [g.strip() for g in response.split(',')]

    def generate_plot_twist(self, title: str, description: str) -> str:
        prompt = f"""Task: Create a movie plot twist
        Movie: {title}
        Original plot: {description}
        Create a surprising but logical alternative ending or plot twist."""
        return self.generate_text(prompt)

    def analyze_movies(self, start_index: int = 0, batch_size: int = 5) -> List[Dict]:
        """Process movies in batches"""
        all_outputs = []

        for i in range(start_index, len(self.df), batch_size):
            batch = self.df.iloc[i:i+batch_size]
            print(f"\nProcessing batch {i//batch_size + 1} of {len(self.df)//batch_size + 1}")

            for _, row in batch.iterrows():
                print(f"\nProcessing: {row['movie_title']}")

                analysis = {
                    'movie_title': row['movie_title'],
                    'original_description': row['description'],
                    'generated_description': self.generate_creative_description(
                        row['movie_title'], row['description']
                    ),
                    'original_genres': row['genres'],
                    'predicted_genres': self.predict_genres(row['description']),
                    'plot_twist': self.generate_plot_twist(
                        row['movie_title'], row['description']
                    ),
                    'cast': row['cast'],
                    'analysis_timestamp': datetime.now().isoformat()
                }
                all_outputs.append(analysis)

                # Save progress after each movie
                self.save_outputs(all_outputs, f'movie_analysis_outputs_batch_{i//batch_size + 1}.json')

                # Add delay to prevent overloading
                time.sleep(2)

            print(f"Completed batch {i//batch_size + 1}")

        # Save final complete output
        self.save_outputs(all_outputs, 'movie_analysis_outputs_complete.json')
        return all_outputs

    def save_outputs(self, outputs: List[Dict], filename: str = 'movie_analysis_outputs.json'):
        """Save outputs to JSON file"""
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(outputs, f, indent=4, ensure_ascii=False)

    def display_outputs(self, outputs: List[Dict]):
        """Display formatted outputs"""
        for output in outputs:
            print("\n" + "="*50)
            print(f"Movie: {output['movie_title']}")
            print("-"*50)
            print(f"Generated Description:\n{output['generated_description']}\n")
            print(f"Original Genres: {output['original_genres']}")
            print(f"Predicted Genres: {', '.join(output['predicted_genres'])}\n")
            print(f"Plot Twist:\n{output['plot_twist']}\n")

def main():
    print("\nInitializing with GPU support...")
    analyzer = MovieAnalyzer()

    # Adjust batch size based on GPU availability
    batch_size = 8 if torch.cuda.is_available() else 5
    print(f"Using batch size: {batch_size}")

    outputs = analyzer.analyze_movies(batch_size=batch_size)
    analyzer.display_outputs(outputs)
    print("\nAnalysis complete! Results saved to 'movie_analysis_outputs_complete.json'")

if __name__ == "__main__":
    main()
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.24.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# GPU is available: True
# GPU being used: Tesla T4
#
# Initializing with GPU support...
# Using batch size: 8
#
# Processing batch 1 of 3
#
# Processing: Inception
#
# Processing: The Shawshank Redemption
#
# Processing: The Dark Knight
#
# Processing: Pulp Fiction
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Processing: The Matrix
#
# Processing: Forrest Gump
#
# Processing: The Godfather
#
# Processing: Jurassic Park
# Completed batch 1
#
# Processing batch 2 of 3
#
# Processing: Titanic
#
# Processing: The Silence of the Lambs
#
# Processing: Avatar
#
# Processing: The Lord of the Rings: The Fellowship of the Ring
#
# Processing: Goodfellas
#
# Processing: Fight Club
#
# Processing: The Green Mile
#
# Processing: Interstellar
# Completed batch 2
#
# Processing batch 3 of 3
#
# Processing: The Avengers
#
# Processing: Schindler's List
#
# Processing: The Lion King
#
# Processing: Star Wars: Episode IV - A New Hope
# Completed batch 3
#
# ==================================================
# Movie: Inception
# --------------------------------------------------
# Generated Description:
# The film is about a speculative art dealer, Leonardo da Vinci, who travels through a world of dreams. He discovers a secret that he intended to keep hidden and a great idea he will bring back to life.
#
# Original Genres: Action, Sci-Fi
# Predicted Genres: Sci-Fi
#
# Plot Twist:
# Inception's narrator, Sean, is a teenage girl who dreams that her mother, Valerie, a scientist, has discovered one of the world's greatest 'unknown' cities. The girl is a girl known as Ariel, and her mother is an older woman named Eve. After waking up and visiting a museum where she finds an ancient human city, Eve realizes that it is a city of giant sea snails. The girl is convinced that she can help the snails by collecting the treasures found there, and to destroy them. They are eventually eliminated from the world, but they still find themselves in the same place, the same city.
#
#
# ==================================================
# Movie: The Shawshank Redemption
# --------------------------------------------------
# Generated Description:
# The Shawshank Redemption is an epic revenge story with a few twists, as the American prison system is turned upside down.
#
# Original Genres: Drama
# Predicted Genres: Drama
#
# Plot Twist:
# Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency, but are unable to reunite.
#
#
# ==================================================
# Movie: The Dark Knight
# --------------------------------------------------
# Generated Description:
# The Dark Knight is a dark comedy about a man who makes himself a hero.
#
# Original Genres: Action, Crime
# Predicted Genres: Action, Comedy, Horror
#
# Plot Twist:
# Detective Superintendent Lena Olmstead (Jamie Lee Curtis) visits Gotham City to investigate the murder of a Jewish man during the Christmas holiday. At the scene is a scene of repressed sexual desires: Joker tries a new sexual trick on Olmstead, a move that ends badly for the innocent crime-fighter, and Olmstead takes Batman in.Between the two confrontations, Olmstead's wife, Mrs. Gotham (Gwen Saunders), is raped by a man at a convenience store. Batman rushes in to save her, but Olmstead's wife is killed.
#
#
# ==================================================
# Movie: Pulp Fiction
# --------------------------------------------------
# Generated Description:
# The two leads, Ralphie Wilson and Peter Ustinov, both play small-time mobsters, who, like other small-time mobsters, have many of the same problems.
#
# Original Genres: Crime, Drama
# Predicted Genres: Crime Comedy
#
# Plot Twist:
# In 1961, the characters are living the life of mobsters in rural Ireland. But one by one, their stories start to collide. One man in particular is a serial killer.
#
#
# ==================================================
# Movie: The Matrix
# --------------------------------------------------
# Generated Description:
# A computer programmer discovers humanity is trapped inside a simulated reality and joins a rebellion to break free.
#
# Original Genres: Sci-Fi, Action
# Predicted Genres: Science Fiction
#
# Plot Twist:
# The film begins with the events of the Matrix when we are introduced to the narrator, Mark Hamill, appearing in a restaurant waiting for a table. We are then introduced to the protagonist, who is trapped in a simulated reality and joins the rebellion to break free.
#
#
# ==================================================
# Movie: Forrest Gump
# --------------------------------------------------
# Generated Description:
# An all-American horseman is brought to America in 1870 to fight for the Union.He is initially a savage musketeer, which is why he is nicknamed The Man and the Machine. The man is a slave and is a man of few words. He is a great leader and an inspiration to soldiers and those seeking fame. He is a man to be reckoned with.The movie portrays Forrest Gump's life and influence in the world on both a personal and political level. The story follows Forrest Gump through times of great trial and insurrection. The movie portrays Forrest Gump as a strong and dependable man, who was able to endure the hardships of war and hardships of the modern world.
#
# Original Genres: Drama, Romance
# Predicted Genres: History
#
# Plot Twist:
# The film opens in October 1947 after the end of the Korean War; it then switches to a scene over the end of the occupation in China. The title character is actually Forrest Gump, who was born in a rural area of North Vietnam in the U.S., and lived there until he was 18.
#
#
# ==================================================
# Movie: The Godfather
# --------------------------------------------------
# Generated Description:
# The Godfather (Marlon Brando) was a gangster that took the wealth of the city of L.A. and turned it into a major international hub for organized crime. With the help of mobsters, he controlled the city's economy and most of its citizens. Brando also held the title of most powerful man in the country. However, the city's gangsters began to dominate the city, and this became an increasingly dangerous situation to lead to the emergence of an organized crime empire. The aging patriarch of an organized crime dynasty (John Wayne), transferred control to his reluctant son (Tyrone Power), who essentially became the city's dominant figure. The movie's narrative is told with the use of a combination of film, video and theater.
#
# Original Genres: Crime, Drama
# Predicted Genres: Crime
#
# Plot Twist:
# The film opens by revealing an abandoned American research ship that was docked in Sicily in 1973. It is revealed to contain a long-lost manuscript of a revolutionary manifesto by Pablo Neruda in which Neruda warns against war, corruption, revolution and murder. The man whom Neruda had promised to destroy, the Italian dictator Enrico Maria Salinas Jr. (José Mara Pizarro), is found dead in his hotel room. The movie then switches to a series of flashbacks showing the life of his character. These flashbacks are revealed chronologically at the end of the original film, but are not in chronological order. The final flashback does not fully explain what happened in 1973, but suggests that it was during the transition from communism to democracy, when Neruda was struggling to fight crime despite his great wealth and success as a criminal boss.
#
#
# ==================================================
# Movie: Jurassic Park
# --------------------------------------------------
# Generated Description:
# The movie portrays the emergence of an intelligent new species of dinosaurs, called the Jurassic Parks whose goal is to occupy the Earth and the lives of the dinosaurs. Each of the dinosaurs have their own specific personality, and each has unique traits that are not inherited. A theme park where the dinosaurs are showcased generates a flurry of people excited to learn more about them.
#
# Original Genres: Adventure, Sci-Fi
# Predicted Genres: Adventure
#
# Plot Twist:
# The film opens on an empty mountaintop with a large rocky hillside. It is revealed that it was once inhabited. A large herd of dinosaurs is shown resting on the hillside.Next day, some 5,000 humans venture into the park. They are attacked by two large, aggressive ape-like creatures. They are joined by 900,000-year-old prehistoric beasts.After the creatures leave the park, the humans discover many dinosaur tracks around the perimeter. Eventually they find the remnants of a prehistoric civilization.They eat prehistoric sea creatures that live in the canyon walls. They reunited with the large herd of dinosaurs.At lunch, they find a large, crow-sized dinosaur that has become attached to a huge chain around its neck. The creature takes them home.As evening sets in for the evening, the herd of dinosaurs heads toward the valley below. They find a large cave that is about two miles (yards) long. They enter by means of a small shaft.The next morning, a massive dinosaur is seen climbing over the cave.It has an enormous be
#
#
# ==================================================
# Movie: Titanic
# --------------------------------------------------
# Generated Description:
# The movie is based on the famous Titanic disaster which occurred in 1912 and became an international phenomenon causing controversy worldwide. The Titanic was used as a movie poster and film prop afterward.
#
# Original Genres: Drama, Romance
# Predicted Genres: Drama, Fantasy
#
# Plot Twist:
# A thirteen-year-old girl sails to the Moon and falls in love with a woman named Maria. After the two are married, Maria and her husband move into a hotel. Maria is concerned about her father's job at the bank, and she sets up a meeting with the head of the bank and is able to convince the bank's head, Mr. Wong, to give Maria a job at the bank.
#
#
# ==================================================
# Movie: The Silence of the Lambs
# --------------------------------------------------
# Generated Description:
# The Silence of the Lambs is a psychological thriller set as a parable about murder, addiction and guilt - and how we learn more about the character of the incarcerated, manipulative killer of a young FBI cadet.
#
# Original Genres: Crime, Thriller
# Predicted Genres: Action, Crime
#
# Plot Twist:
# The police cadet, scheming to save the child, has hired an old comrade, the unfaithful obnoxious Mr. Morgan to help her. After the deceitful Morgan returns and persuades her he has to take her to his home in the countryside, where the child's nanny, Mrs. Blackwood, lives.
#
#
# ==================================================
# Movie: Avatar
# --------------------------------------------------
# Generated Description:
# Avatar is a story about a marine officer who leaves his home planet Earth to travel to a second planet. After arriving on the planet, the main character, a paraplegic marine, is dispatched to meet his next destination, a planet in the Solar System. While aboard the ship, the main character is challenged to balance his love for his fellow marine and his obligation to protect the Earth. The story revolves around the crew of the ship, a group of misfits, who are separated from the main characters after a fight on their flight. Their lives are disrupted when their ship is destroyed by a storm, which leaves the boat wrecked. The boat is sent to the ocean to search for survivors. The marines eventually find the ship wreckage and its crew. The boat is eventually found by a mysterious alien spacecraft, whose robot insignia lights up the night sky. Soon the lights start to flicker down on the ship, telling the passengers that it is their last chance. The survivors tell the marines that the lights are caused by an antimatter weapon, a kind of explosive weapon. They have to use it
#
# Original Genres: Sci-Fi, Adventure
# Predicted Genres: Drama, Sci-Fi, Horror
#
# Plot Twist:
# Pandora is a dummy swashbuckler that was released by his employer in exchange for services.
#
#
# ==================================================
# Movie: The Lord of the Rings: The Fellowship of the Ring
# --------------------------------------------------
# Generated Description:
# The Lord of the Rings: The Fellowship of the Ring is a sequel to the popular and influential Lord of the Rings film trilogy. This version focuses on Hobbit Lord Argon, who was a real character in the first film. His story follows a group of Hobbit children who travel to Middle-Earth to find their dadâa wizard. Upon their arrival, in Middle-Earth, they befriend an elf called Aragorn, who they help to defeat the demonic acolytes known as "the Seven Dwarfs."Aragorn is a young wizard and the three of them embark on a quest to destroy the Seven Dwarfs, who are a group of demonic creatures created by Sauron. The three go on a journey to destroy a powerful ring and defeat the dark lord who created them.
#
# Original Genres: Fantasy, Adventure
# Predicted Genres: Action, Adventure, Fantasy
#
# Plot Twist:
# In the years following the death of Hobbit, the war breaks out between the two sides of the conflict. In the last year of the war, the Two Towers were under attack by the Empire. Hobbit and his friends are trapped in an undefined future in the past. A large army is summoned to help them escape.
#
#
# ==================================================
# Movie: Goodfellas
# --------------------------------------------------
# Generated Description:
# An entertaining romantic comedy about the life of Henry Hill : a gangster whose relationship with his wife Karen and many of his contemporaries as well as his daughters gets him involved in an accidental murder case.
#
# Original Genres: Crime, Biography
# Predicted Genres: Business
#
# Plot Twist:
# In the days following the city's bombing, hundreds of bomb-sniffing dogs are parked on the roof of Henry Hill's house in East Orange, New Jersey. After a year of preparation, the dogs are stuffed into crates and taken to a mob-controlled warehouse, where they are tortured and mutilated. Despite their grisly natures, one is saved by the owner of the warehouse, who thinks, "There are no better losers around."
#
#
# ==================================================
# Movie: Fight Club
# --------------------------------------------------
# Generated Description:
# The premise of this movie is that two unlikely people find themselves bonded by their mutual hatred of women and their sexuality, and then embark on a journey to change their lives for the better.
#
# Original Genres: Drama, Thriller
# Predicted Genres: Action, Thriller, Thriller
#
# Plot Twist:
# An insomniac office worker, and a devil-may-care soapmaker form an underground fight club and soon, they grow to attract a great many people.
#
#
# ==================================================
# Movie: The Green Mile
# --------------------------------------------------
# Generated Description:
# A tale of a gentle prison guard who discovers that a death row inmate possesses mysterious healing powers.
#
# Original Genres: Crime, Drama, Fantasy
# Predicted Genres: Drama
#
# Plot Twist:
# The film's title is a play on a quote by Samuel Beckett, who was portrayed by George C. Scott in the film.
#
#
# ==================================================
# Movie: Interstellar
# --------------------------------------------------
# Generated Description:
# Interstellar is a 2008 space film directed by Ridley Scott.
#
# Original Genres: Sci-Fi, Adventure
# Predicted Genres: Drama
#
# Plot Twist:
# The team of explorers travel through a wormhole in space to ensure humanity's survival.
#
#
# ==================================================
# Movie: The Avengers
# --------------------------------------------------
# Generated Description:
# The Avengers is an entertaining sequel to the 1980s movie  Avengers (Red). The sequel  Starcrash  also stars Michael Keaton, Hugh Jackman, Donald Sutherland, and James Cousins. The movie begins with the movie   Red'  the original film, but the stories of the original movies   Silversword'  Iron Man  Silver Surfer  and Iron Man 2 are also revisited. Most of the original actors are brought back to reprise their roles, but the main difference is the costumes. The opening sequence features shots of the Iron Man Studios and the famous "Hercules" helicopter. This is repeated over and over again with the Iron Man/Hercules helicopter in the first scene of the movie. The Iron Man/Hercules helicopter reprises its role in the second scene, as do the opening shots of the helicopter as it floats on a blue, green, and red ocean.  The Avengers'  2010  2009
#
# Original Genres: Action, Sci-Fi
# Predicted Genres: Science Fiction
#
# Plot Twist:
# A new villain has arrived on Earth, named Zod, who is disguised as a human. He was created from the remnants of the Original Zombies, and was a threat to the Earth's people. The previous hero became superhuman and fought his way into the Avengers' team. When an alien attacked and destroyed The Avengers team, Zod and his new companion the Wolverine, he became one of the last heroes to flee.
#
#
# ==================================================
# Movie: Schindler's List
# --------------------------------------------------
# Generated Description:
# Schindler's List is a 1933 German-Canadian film about a man named Oskar Schindler, who in 1932 begins his own business to supply labor to the Nazi Party and is subsequently arrested, tried, and imprisoned within the German prison system.
#
# Original Genres: Biography, Drama
# Predicted Genres: Drama
#
# Plot Twist:
# In addition to the Holocaust, the Schindler's List consists of "fantasies", short stories and other erotic stuff, and Schindler has a habit of writing them down.
#
#
# ==================================================
# Movie: The Lion King
# --------------------------------------------------
# Generated Description:
# The lion prince must overcome tragedy and take his rightful place as king of the Pride Lands.
#
# Original Genres: Animation, Adventure
# Predicted Genres: Drama
#
# Plot Twist:
# The lion king's parents are assassinated, and the new prince inherits the throne, becoming the king of Pride Lands.
#
#
# ==================================================
# Movie: Star Wars: Episode IV - A New Hope
# --------------------------------------------------
# Generated Description:
# The film tells the story of a young boy and his journey from a Jedi Knight to a pilot and what it means to be a stewardess.
#
# Original Genres: Sci-Fi, Adventure
# Predicted Genres: Sci-Fi
#
# Plot Twist:
# The Empire is winning the Battle of Endor, wherein the new generation of Jedi are being forced to sacrifice themselves to conquer a new race of Jedi for the pleasure of the fallen.More resistance forces are attempting to fight the Empire, too. The Jedi are determined to stop the Empire, and are using their greatest strength to defeat them.It is now up to Luke Skywalker and Darth Vader to stop them. The Empire's only hope and hope to defeat the Jedi is to kill the Jedi. They intend to defeat the Jedi by encircling and destroying the Empire's worlds.
#
#
# Analysis complete! Results saved to 'movie_analysis_outputs_complete.json'
